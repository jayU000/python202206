# %%
# 지니 차트 크롤링


# 멜론과 지니의 경우 벅스와는 달리 페이지 소스 크롤링을 보안상의 이유로 거부한다.
# 따라서 페이지 소스를 서버에서 넘겨 받지 말고 (거부하기 때문에)
# 브라우저로 날라온 소스를 크롤링한다.

# !pip install selenium

import time
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import pandas as pd

driver = webdriver.Chrome('chromedriver.exe')

driver.get('https://www.genie.co.kr/chart/top200')
response = driver.page_source

soup = bs(response)

songs = soup.select('tr.list')

# title = song.select('a.title')[0].text.strip()
# # 곡명 추출

# singer = song.select('a.artist')[0].text
# # 가수명 추출

# rank = song.select('td.number')[0].text.split('\n')[0]
# # 순위 추출

# print(title)
# print(singer)
# print(rank)

song_data = []

for song in songs :
    title = song.select('a.title')[0].text.split('\n')[-1].strip()
    singer = song.select('a.artist')[0].text
    rank = song.select('td.number')[0].text.split('\n')[0]

    song_data.append(['Genie', rank, title, singer])

# time.sleep(2)

# print(song_data)

page2 = driver.find_element_by_css_selector('div.rank-page-nav > a:nth-child(2)')
page2.click()
response = driver.page_source

soup = bs(response)

songs = soup.select('tr.list')

for song in songs :
    title = song.select('a.title')[0].text.split('\n')[-1].strip()
    singer = song.select('a.artist')[0].text
    rank = song.select('td.number')[0].text.split('\n')[0]

    song_data.append(['Genie', rank, title, singer])

print(song_data)

# df = pd.DataFrame(song_data, columns=['차트명', '순위', '타이틀', '가수'])
# print(df)

# df.to_excel('genie.xlsx', index=False)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_36148\2286429111.py:15: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# C:\Users\PC\AppData\Local\Temp\ipykernel_36148\2286429111.py:50: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   page2 = driver.find_element_by_css_selector('div.rank-page-nav > a:nth-child(2)')
# ...

# %%
# 코랩에서 하는 방법

# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin

# options = webdriver.ChromeOptions()
# options.add_argument('--headless')        # Head-less 설정
# options.add_argument('--no-sandbox')
# options.add_argument('--disable-dev-shm-usage')
# driver = webdriver.Chrome('chromedriver', options=options)
# Out:
# ...
# 'apt-get'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'apt'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'cp'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# 네이버 영화 랭킹 평점순 (현재상영영화)
# 순위, 영화명, 평점
# 크롤링하려 데이터프레임으로 만들어 엑셀 파일 제출

# !pip install selenium

import time
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import pandas as pd

driver = webdriver.Chrome('chromedriver.exe')

driver.get('https://movie.naver.com/movie/sdb/rank/rmovie.naver')
response = driver.page_source
soup = bs(response)

movies = soup.select('table.list_ranking > tbody > tr')

movie_data = []
rank = 0
add = 1

for movie in movies :

    try : 
        if movie.select('td.title')[0].text.strip() != '' :
            title = movie.select('td.title')[0].text.strip()
    except IndexError :
        continue

    try : 
        if movie.select_one('td.ac:nth-child(1) > img') is not None: #old_content > table > tbody > tr:nth-child(28) > td:nth-child(1) > img
            rank += add
            add = 1
        else :           
            add += 1
    except IndexError :
        continue

    movie_data.append(['NaverMovie', rank, title, score])


print(movie_data)

# df = pd.DataFrame(song_data, columns=['차트명', '순위', '타이틀', '가수'])

# df.to_excel('genie.xlsx', index=False)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_36148\2774791442.py:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# ...

# %%
# 네이버 영화 랭킹 평점순 (현재상영영화)
# 순위, 영화명, 평점
# 크롤링하려 데이터프레임으로 만들어 엑셀 파일 제출

# !pip install selenium

import time
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import pandas as pd

driver = webdriver.Chrome('chromedriver.exe')

driver.get('https://movie.naver.com/movie/sdb/rank/rmovie.naver')
response = driver.page_source
soup = bs(response)
soup

# movies = soup.select('table.list_ranking > tbody > tr')

# movie_data = []

# # songs = soup.select('tr.list')
# # print(len(songs))
# rank = 0
# add = 1

# for movie in movies :

#     try : 
#         if movie.select('td.title')[0].text.strip() != '' :
#             title = movie.select('td.title')[0].text.strip()
#     except IndexError :
#         continue

#     try : 
#         if movie.select_one('td.ac:nth-child(1) > img') is not None: #old_content > table > tbody > tr:nth-child(28) > td:nth-child(1) > img
#             rank += add
#             add = 1
#         else :           
#             add += 1
#     except IndexError :
#         continue


#     movie_data.append(['NaverMovie', rank, title, score])


# movies = soup.select('table.list_ranking > tbody > tr')

# movie_data = []

# songs = soup.select('tr.list')
# print(len(songs))

rankingPageBtn = driver.find_element_by_css_selector('#old_content > div.tab_type_6 > ul > li:nth-child(3) > a > img') 
rankingPageBtn.click()

response = driver.page_source
soup = bs(response)
soup

movie_data = []

rank = 0
add = 1

for movie in movies :

    try : 
        if movie.select('td.title')[0].text.strip() != '' :
            title = movie.select('td.title')[0].text.strip()
    except IndexError :
        continue

    try : 
        if movie.select_one('td.ac:nth-child(1) > img') is not None: #old_content > table > tbody > tr:nth-child(28) > td:nth-child(1) > img
            rank += add
            add = 1
        else :           
            add += 1
    except IndexError :
        continue

    movie_data.append(['NaverMovie', rank, title, score])

time.sleep(3)

print(movie_data)

songs = soup.select('tr.list')

for movie in movie :
    title = song.select('a.title')[0].text.split('\n')[-1].strip()
    singer = song.select('a.artist')[0].text
    rank = song.select('td.number')[0].text.split('\n')[0]

    song_data.append(['Genie', rank, title, singer])

print(song_data)

# df = pd.DataFrame(song_data, columns=['차트명', '순위', '타이틀', '가수'])
# df.to_excel('genie.xlsx', index=False)

# %%
# 네이버 영화 랭킹 평점순 (현재상영영화)
# 순위, 영화명, 평점
# 크롤링하려 데이터프레임으로 만들어 엑셀 파일 제출

# !pip install selenium

import time
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import pandas as pd

driver = webdriver.Chrome('chromedriver.exe')

driver.get('https://movie.naver.com/movie/sdb/rank/rmovie.naver')

rankingPageBtn = driver.find_element_by_css_selector('#old_content > div.tab_type_6 > ul > li:nth-child(3) > a > img') 
rankingPageBtn.click()

response = driver.page_source
soup = bs(response)

movies = soup.select('table.list_ranking > tbody > tr')

response = driver.page_source
soup = bs(response)
soup

movie_data = []

rank = 0
add = 1

for movie in movies :

    try : 
        if movie.select('td.title')[0].text.strip() != '' :
            title = movie.select('td.title')[0].text.strip()
    except IndexError :
        continue

    try : 
        if movie.select_one('td.ac:nth-child(1) > img') is not None: #old_content > table > tbody > tr:nth-child(28) > td:nth-child(1) > img
            rank += add
            add = 1
        else :           
            add += 1
    except IndexError :
        continue

    movie_data.append(['NaverMovie', rank, title, score])



# time.sleep(3)

print(movie_data)

# page2 = driver.find_element_by_css_selector('div.rank-page-nav > a:nth-child(2)')
# page2.click()
# response = driver.page_source

# soup = bs(response)
# songs = soup.select('tr.list')

# for movie in movie :
#     title = song.select('a.title')[0].text.split('\n')[-1].strip()
#     singer = song.select('a.artist')[0].text
#     rank = song.select('td.number')[0].text.split('\n')[0]

#     song_data.append(['Genie', rank, title, singer])


# print(song_data)

# df = pd.DataFrame(song_data, columns=['차트명', '순위', '타이틀', '가수'])

# df.to_excel('genie.xlsx', index=False)

# %%
# 날씨 크롤링

# 현재 온도 : 23.4
# 현재 상테 : 흐림

import time
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import pandas as pd

driver = webdriver.Chrome('chromedriver.exe')

driver.get('https://weather.naver.com/')

response = driver.page_source
soup = bs(response)

temp = soup.select('#now > div > div.weather_area > div.weather_now > div > strong')[0].text[-6::].strip()
now = soup.select('#now > div > div.weather_area > div.weather_now > p > span.weather')[0].text

print(f'현재 온도 : {temp}')
print(f'현재 상태 : {now}')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_36148\3189783160.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# 현재 온도 : 24.3°
# 현재 상태 : 흐림

# %%
# 비트코인 현재 가격 조회 

import time
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import pandas as pd

driver = webdriver.Chrome('chromedriver.exe')

driver.get('https://www.bithumb.com/')

response = driver.page_source
soup = bs(response)

btcPrince = soup.select('#assetRealBTC_KRW')[0].text

print(btcPrince)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_36148\3122434481.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# 38,584,000 원

# %%
# !pip install bs4
# Out:
# ...
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=8d130faaa78b8f95f8a36f42239ab86c3ffb911c97da9ba4c1b9fd8f829a45dc
#   Stored in directory: c:\users\pc\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# ...
